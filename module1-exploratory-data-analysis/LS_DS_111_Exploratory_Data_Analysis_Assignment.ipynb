# %% [markdown]
# <a href="https://colab.research.google.com/github/popkdodge/DS-Unit-1-Sprint-1-Data-Wrangling-and-Storytelling/blob/master/module1-exploratory-data-analysis/LS_DS_111_Exploratory_Data_Analysis_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice Loading and Exploring Datasets
#
# This assignment is purposely open-ended. You will be asked to load datasets from the [UC-Irvine Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php).
#
# Even though you maybe using different datasets than your fellow classmates, try and be supportive and assist each other in the challenges that you are facing. You will only deepend your understanding of these topics as you work to assist one another. Many popular UCI datasets face similar data loading challenges.
#
# Remember that the UCI datasets do not necessarily have a file type of `.csv` so it's important that you learn as much as you can about the dataset before you try and load it. See if you can look at the raw text of the file either locally or using the `!curl` shell command -or in some other way before you try and read it in as a dataframe. This will help you catch what would otherwise be unforseen problems.
#
# Feel free to embellish this notebook with additional markdown cells,code cells, comments, graphs, etc. Whatever you think helps adequately address the questions.

# %% [markdown]
# ## 1) Load a dataset from UCI (via its URL)
#
# Please navigate to the home page and choose a dataset (other than the Adult dataset) from the "Most Popular" section on the right-hand side of the home page. Load the dataset via its URL and check the following (show your work):
#
# - Are the headers showing up properly?
# - Look at the first 5 and the last 5 rows, do they seem to be in order?
# - Does the dataset have the correct number of rows and columns as described in the UCI page?
#  - Remember, that UCI does not count the y variable (column of values that we might want to predict via a machine learning model) as an "attribute" but rather as a "class attribute" so you may end up seeing a number of columns that is one greater than the number listed on the UCI website.
# - Does UCI list this dataset as having missing values? Check for missing values and see if your analysis corroborates what UCI reports?
# - if `NaN` values or other missing value indicators are not being detected by `df.isnull().sum()` find a way to replace whatever is indicating the missing values with `np.NaN`.
# - Use the .describe() function in order to see the summary statistics of both the numeric and non-numeric columns.

# %%
# TODO your work here!
# And note you should write comments, descriptions, and add new
# code and text blocks as needed
import pandas as pd
import numpy as np

#for my dataset I am using the Wine dataset

wine_dataset = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data'

#wine = pd.read_csv(wine_dataset) I comment out and will restart agian. Below

#I am checking through the dataset raw files prior to check
'''From my assessment this data is seperate by a " ,"
  and should not have any missing values: It is stated on ULC website to also not have ny missing values
  this is also missing column headers value I should figure it out from ULC website and create a value that contain all the missing value.
'''
wine_column_header = ['Alcohol', 'Malic_Acid', 'Ash', 'Alcalinity_of_ash', 'Magnesium', 'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols', 'Proanthrocyanins', 'Color_intensity', 'Hue', 'OD280/OD315', 'Proline']
wine = pd.read_csv(wine_dataset, names=wine_column_header)
wine.head()
# Out:
#    Alcohol  Malic_Acid   Ash  ...   Hue  OD280/OD315  Proline
# 1    14.23        1.71  2.43  ...  1.04         3.92     1065
# 1    13.20        1.78  2.14  ...  1.05         3.40     1050
# 1    13.16        2.36  2.67  ...  1.03         3.17     1185
# 1    14.37        1.95  2.50  ...  0.86         3.45     1480
# 1    13.24        2.59  2.87  ...  1.04         2.93      735
#
# [5 rows x 13 columns]

# %%
wine.tail()
# Out:
#    Alcohol  Malic_Acid   Ash  ...   Hue  OD280/OD315  Proline
# 3    13.71        5.65  2.45  ...  0.64         1.74      740
# 3    13.40        3.91  2.48  ...  0.70         1.56      750
# 3    13.27        4.28  2.26  ...  0.59         1.56      835
# 3    13.17        2.59  2.37  ...  0.60         1.62      840
# 3    14.13        4.10  2.74  ...  0.61         1.60      560
#
# [5 rows x 13 columns]

# %%
wine.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  ...         Hue  OD280/OD315      Proline
# count  178.000000  178.000000  178.000000  ...  178.000000   178.000000   178.000000
# mean    13.000618    2.336348    2.366517  ...    0.957449     2.611685   746.893258
# std      0.811827    1.117146    0.274344  ...    0.228572     0.709990   314.907474
# min     11.030000    0.740000    1.360000  ...    0.480000     1.270000   278.000000
# 25%     12.362500    1.602500    2.210000  ...    0.782500     1.937500   500.500000
# 50%     13.050000    1.865000    2.360000  ...    0.965000     2.780000   673.500000
# 75%     13.677500    3.082500    2.557500  ...    1.120000     3.170000   985.000000
# max     14.830000    5.800000    3.230000  ...    1.710000     4.000000  1680.000000
#
# [8 rows x 13 columns]

# %%
#checking for the shape and compareing
wine.shape
#yes, the data match with the rows and column as stated in ULC website
# Out:
# (178, 13)

# %%
#checking for Nan Values
wine.isnull().sum()
#It is not missing nay nan values.
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Alcalinity_of_ash       0
# Magnesium               0
# Total_phenols           0
# Flavanoids              0
# Nonflavanoid_phenols    0
# Proanthrocyanins        0
# Color_intensity         0
# Hue                     0
# OD280/OD315             0
# Proline                 0
# dtype: int64

# %%
# I have answer below. Answer is Italisize.

# %% [markdown]
# - Are the headers showing up properly? *No.*
# - Look at the first 5 and the last 5 rows, do they seem to be in order?
#  *The index do seem to group the wine in to three group however I do not see a pattern to explain why.*
# - Does the dataset have the correct number of rows and columns as described in the UCI page? *Yes, the correct numbers of rows and colums match with what is stated on UCI page.*
#  - Remember, that UCI does not count the y variable (column of values that we might want to predict via a machine learning model) as an "attribute" but rather as a "class attribute" so you may end up seeing a number of columns that is one greater than the number listed on the UCI website.
# - Does UCI list this dataset as having missing values? Check for missing values and see if your analysis corroborates what UCI reports?*No, this dataset do not contain any missing Nan Value*
# - if `NaN` values or other missing value indicators are not being detected by `df.isnull().sum()` find a way to replace whatever is indicating the missing values with `np.NaN`.
# - Use the .describe() function in order to see the summary statistics of both the numeric and non-numeric columns.

# %% [markdown]
# ## 2) Load a dataset from your local machine.
# Choose a second dataset from the "Popular Datasets" listing on UCI, but this time download it to your local machine instead of reading it in via the URL. Upload the file to Google Colab using the files tab in the left-hand sidebar or by importing `files` from `google.colab` The following link will be a useful resource if you can't remember the syntax: <https://towardsdatascience.com/3-ways-to-load-csv-files-into-colab-7c14fcbdcb92>
#
# - Answer all of the same bullet point questions from part 1 again on this new dataset.

# %%
# BELOW IS THE ANSWER

# %% [markdown]
# *   Header did not shown properly and I have to create a name list for the columns.
# *   They appear to be ordered from the highest cost to the lowest cost.
# *   The dataset do not contain any values and this is stated on the UCI website and I have skim through the raw data.
# *   The column and rows count have an extar y variable and the y variable is acceptablilty.

# %%
# TODO your work here!
# And note you should write comments, descriptions, and add new
# code and text blocks as needed

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9f5ad149-6a7c-4c81-b7b4-f873d4cd8783" name="files[]" multiple disabled />
#      <output id="result-9f5ad149-6a7c-4c81-b7b4-f873d4cd8783">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car.data to car.data

# %%
car = pd.read_csv('car.data')
car.head() #it appear to be missing column headers
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc
# 3  vhigh   vhigh  2   2    med   med  unacc
# 4  vhigh   vhigh  2   2    med  high  unacc

# %%
car.describe()
# Out:
#         Cost MaintanceCost Doors Person Lug_boot_size Safety Acceptability
# count   1728          1728  1728   1728          1728   1728          1728
# unique     4             4     4      3             3      3             4
# top     high          high     3   more         small   high         unacc
# freq     432           432   432    576           576    576          1210

# %%
car_column_header = ["Cost", "MaintanceCost", "Doors", "Person", "Lug_boot_size", "Safety", "Acceptability"]

# %%
car = pd.read_csv('car.data', names=car_column_header)

# %%
car.head()
# Out:
#     Cost MaintanceCost Doors Person Lug_boot_size Safety Acceptability
# 0  vhigh         vhigh     2      2         small    low         unacc
# 1  vhigh         vhigh     2      2         small    med         unacc
# 2  vhigh         vhigh     2      2         small   high         unacc
# 3  vhigh         vhigh     2      2           med    low         unacc
# 4  vhigh         vhigh     2      2           med    med         unacc

# %%
car.tail()
# Out:
#      Cost MaintanceCost  Doors Person Lug_boot_size Safety Acceptability
# 1723  low           low  5more   more           med    med          good
# 1724  low           low  5more   more           med   high         vgood
# 1725  low           low  5more   more           big    low         unacc
# 1726  low           low  5more   more           big    med          good
# 1727  low           low  5more   more           big   high         vgood

# %%
car.shape
# Out:
# (1728, 7)

# %% [markdown]
# ## 3) Make Crosstabs of the Categorical Variables
#
# Take whichever of the above datasets has more categorical variables and use crosstabs to tabulate the different instances of the categorical variables.

# %%
# Your Code Here
pd.crosstab(car['Cost'], car['MaintanceCost'])
# Maintance cost seem to match evenly with the Cost of the vehicle.
# Out:
# MaintanceCost  high  low  med  vhigh
# Cost
# high            108  108  108    108
# low             108  108  108    108
# med             108  108  108    108
# vhigh           108  108  108    108

# %%
pd.crosstab(car['Cost'], car['Acceptability'])
# Out:
# Acceptability  acc  good  unacc  vgood
# Cost
# high           108     0    324      0
# low             89    46    258     39
# med            115    23    268     26
# vhigh           72     0    360      0

# %%
pd.crosstab(car['Acceptability'], car['Cost']).plot();

# %% [markdown]
# ## 4) Explore the distributions of the variables of the dataset using:
# - Histograms
# - Scatterplots
# - Density Plots

# %%
pd.crosstab(car['Acceptability'], car['MaintanceCost']).plot(kind='bar');

# %%
car.plot.scatter('Cost', 'Acceptability');

# %%
car['Acceptability'].plot.density();
#THIS ENTIRE DATASET IS ALL CATEROGICAL SO UNLESS I DO SOME FEATURES ENGINEERING I WILL NOT BEABLE TO PLOT THE PLOT DENSITY
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-713cd5870e60> in <module>()
# ----> 1 car['Acceptability'].plot.density();
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in kde(self, bw_method, ind, **kwargs)
#    1286             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1287         """
# -> 1288         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1289
#    1290     density = kde
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
car['Acceptability'].value_counts().sort_index().plot();

# %% [markdown]
# ## 5) Create at least one visualization from a crosstab:
#
# Remember that a crosstab is just a dataframe and can be manipulated in the same way by row index, column, index, or column/row/cell position.

# %%
pd.crosstab(car['Acceptability'], car['Cost']).plot();

# %% [markdown]
# ## Stretch Goals
#
# The following additional study tasks are optional, they are intended to give you an opportunity to stretch yourself beyond the main requirements of the assignment. You can pick and choose from the below, you do not need to complete them in any particular order.
#
# ### - Practice Exploring other Datasets
#
# ### -  Try using the Seaborn plotting library's "Pairplot" functionality in order to explore all of the possible histograms and scatterplots of your dataset all at once:
#
# [Seaborn Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)
#
# ### - Turn some of the continuous variables into categorical variables by binning the values using:
# - [pd.cut()](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.cut.html)
# - [pd.qcut()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html)
# - <https://stackoverflow.com/questions/30211923/what-is-the-difference-between-pandas-qcut-and-pandas-cut>
#
# And then use crosstabs to compare/visualize these binned variables against the other variables.
#
#
# ### - Other types and sources of data
# Not all data comes in a nice single file - for example, image classification involves handling lots of image files. You still will probably want labels for them, so you may have tabular data in addition to the image blobs - and the images may be reduced in resolution and even fit in a regular csv as a bunch of numbers.
#
# If you're interested in natural language processing and analyzing text, that is another example where, while it can be put in a csv, you may end up loading much larger raw data and generating features that can then be thought of in a more standard tabular fashion.
#
# Overall you will in the course of learning data science deal with loading data in a variety of ways. Another common way to get data is from a database - most modern applications are backed by one or more databases, which you can query to get data to analyze. We'll cover this more in our data engineering unit.
#
# How does data get in the database? Most applications generate logs - text files with lots and lots of records of each use of the application. Databases are often populated based on these files, but in some situations you may directly analyze log files. The usual way to do this is with command line (Unix) tools - command lines are intimidating, so don't expect to learn them all at once, but depending on your interests it can be useful to practice.
#
# One last major source of data is APIs: https://github.com/toddmotto/public-apis
#
# API stands for Application Programming Interface, and while originally meant e.g. the way an application interfaced with the GUI or other aspects of an operating system, now it largely refers to online services that let you query and retrieve data. You can essentially think of most of them as "somebody else's database" - you have (usually limited) access.
#
# *Stretch goal* - research one of the above extended forms of data/data loading. See if you can get a basic example working in a notebook. Image, text, or (public) APIs are probably more tractable - databases are interesting, but there aren't many publicly accessible and they require a great deal of setup.

# %%
iris_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(iris_url)

# %%
iris.head()
# Out:
#    Sepal_len  Sepal_wid  Petal_len  Petal_wid        Class
# 0        5.1        3.5        1.4        0.2  Iris-setosa
# 1        4.9        3.0        1.4        0.2  Iris-setosa
# 2        4.7        3.2        1.3        0.2  Iris-setosa
# 3        4.6        3.1        1.5        0.2  Iris-setosa
# 4        5.0        3.6        1.4        0.2  Iris-setosa

# %%
iris_column_header = ['Sepal_len', 'Sepal_wid', 'Petal_len', 'Petal_wid', 'Class']

# %%
iris = pd.read_csv(iris_url, names=iris_column_header)

# %%
iris.head()
# Out:
#    Sepal_len  Sepal_wid  Petal_len  Petal_wid        Class
# 0        5.1        3.5        1.4        0.2  Iris-setosa
# 1        4.9        3.0        1.4        0.2  Iris-setosa
# 2        4.7        3.2        1.3        0.2  Iris-setosa
# 3        4.6        3.1        1.5        0.2  Iris-setosa
# 4        5.0        3.6        1.4        0.2  Iris-setosa

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)

# %%
seaborn_pairplot = sns.pairplot(iris)

# %%
seaborn_pairplot_hue = sns.pairplot(iris, hue="Class",palette="husl", markers=["o", "s", "D"] )

# %%
# I was able to read the documentation and match the seaborn example with the variable I personally set.

# %%
seaborn_pairplot_hue = sns.pairplot(iris, hue="Class", kind="reg" )

# %%
#I am going to use the wine dataset to represent the q cut vs cut pd.cut() vs pd.qcut()  because the wine dataset is completely continous for all columns.

# %%
wine.head(20)
# Out:
#    Alcohol  Malic_Acid   Ash  ...  Proline     Alcohol_cut      Alcohol_qcut
# 1    14.23        1.71  2.43  ...     1065  (14.07, 14.83]   (13.756, 14.83]
# 1    13.20        1.78  2.14  ...     1050  (12.55, 13.31]   (12.76, 13.282]
# 1    13.16        2.36  2.67  ...     1185  (12.55, 13.31]   (12.76, 13.282]
# 1    14.37        1.95  2.50  ...     1480  (14.07, 14.83]   (13.756, 14.83]
# 1    13.24        2.59  2.87  ...      735  (12.55, 13.31]   (12.76, 13.282]
# 1    14.20        1.76  2.45  ...     1450  (14.07, 14.83]   (13.756, 14.83]
# 1    14.39        1.87  2.45  ...     1290  (14.07, 14.83]   (13.756, 14.83]
# 1    14.06        2.15  2.61  ...     1295  (13.31, 14.07]   (13.756, 14.83]
# 1    14.83        1.64  2.17  ...     1045  (14.07, 14.83]   (13.756, 14.83]
# 1    13.86        1.35  2.27  ...     1045  (13.31, 14.07]   (13.756, 14.83]
# 1    14.10        2.16  2.30  ...     1510  (14.07, 14.83]   (13.756, 14.83]
# 1    14.12        1.48  2.32  ...     1280  (14.07, 14.83]   (13.756, 14.83]
# 1    13.75        1.73  2.41  ...     1320  (13.31, 14.07]  (13.282, 13.756]
# 1    14.75        1.73  2.39  ...     1150  (14.07, 14.83]   (13.756, 14.83]
# 1    14.38        1.87  2.38  ...     1547  (14.07, 14.83]   (13.756, 14.83]
# 1    13.63        1.81  2.70  ...     1310  (13.31, 14.07]  (13.282, 13.756]
# 1    14.30        1.92  2.72  ...     1280  (14.07, 14.83]   (13.756, 14.83]
# 1    13.83        1.57  2.62  ...     1130  (13.31, 14.07]   (13.756, 14.83]
# 1    14.19        1.59  2.48  ...     1680  (14.07, 14.83]   (13.756, 14.83]
# 1    13.64        3.10  2.56  ...      845  (13.31, 14.07]  (13.282, 13.756]
#
# [20 rows x 15 columns]

# %%
wine["Alcohol_cut"] = pd.cut(wine.Alcohol,5)

# %%
wine["Alcohol_qcut"] = pd.qcut(wine.Alcohol,5)

# %%
wine["Alcohol_cut"].value_counts()
# Out:
# (13.31, 14.07]     50
# (11.79, 12.55]     49
# (12.55, 13.31]     48
# (14.07, 14.83]     19
# (11.026, 11.79]    12
# Name: Alcohol_cut, dtype: int64

# %%
wine["Alcohol_qcut"].value_counts()
# Out:
# (11.029, 12.25]     37
# (13.756, 14.83]     36
# (12.76, 13.282]     36
# (13.282, 13.756]    35
# (12.25, 12.76]      34
# Name: Alcohol_qcut, dtype: int64

# %% [markdown]
# The cut will seperate the data in to 5 even cuts so it does not account for distribution .
# The qcut will sperate the data into 5 uneven cuts but focus on even distribution.
